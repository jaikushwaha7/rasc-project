# %%
import json
data = json.load(open("data/processed/vg_5k_subset.json"))
print("Images:", len(data))
print("Example predicates:", {r["predicate"] for r in data[0]["relationships"]})
# Out:
# Images: 5000
# Example predicates: {'behind'}

# %%
# %run ./src/data/test_one_image2.py --subset data/processed/vg_5k_subset.json --index 9
# Out:
# Displaying Image ID: 2391850

# %%
# %run ./src/data/test_one_image2.py --subset data/processed/vg_5k_subset.json --index 9
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='Image Index:', max=4999), Outpu…

# %%
# labels for yolo.yaml
import json
labels = json.load(open("data/processed/label_map.json"))
names = [None] * len(labels)
for k, v in labels.items():
    names[v] = k
print("\n".join([f"  - {n}" for n in names]))
